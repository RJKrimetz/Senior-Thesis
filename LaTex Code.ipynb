# %%
import pandas as pd

# %%
df = pd.read_csv('Remaining_Tickers.csv')
df
# Out:
#      Unnamed: 0 Ticker       Start         End  NA_Count  Days  Percent_NA
# 0             0   LUMN  2020-09-18  2022-12-30         0   833    0.000000
# 1             1     VZ  2016-01-04  2022-12-30       120  2552    0.000735
# 2             2      T  2016-01-04  2022-12-30       468  2552    0.002865
# 3             3    DIS  2016-01-04  2022-12-30         0  2552    0.000000
# 4             4   TTWO  2016-01-04  2022-12-30         0  2552    0.000000
# ..          ...    ...         ...         ...       ...   ...         ...
# 482         494    PEG  2016-01-04  2022-12-30      4992  2552    0.030564
# 483         495    SRE  2016-01-04  2022-12-30       648  2552    0.003967
# 484         496    WEC  2016-01-04  2022-12-30      3636  2552    0.022262
# 485         497    CNP  2016-01-04  2022-12-30      1164  2552    0.007127
# 486         498    AWK  2016-01-04  2022-12-30      1044  2552    0.006392
#
# [487 rows x 7 columns]

# %%
print(df.head(30).to_latex(index=False))
# Out:
# \begin{tabular}{rlllrrr}
# \toprule
#  Unnamed: 0 & Ticker &      Start &        End &  NA\_Count &  Days &  Percent\_NA \\
# \midrule
#           0 &   LUMN & 2020-09-18 & 2022-12-30 &         0 &   833 &    0.000000 \\
#           1 &     VZ & 2016-01-04 & 2022-12-30 &       120 &  2552 &    0.000735 \\
#           2 &      T & 2016-01-04 & 2022-12-30 &       468 &  2552 &    0.002865 \\
#           3 &    DIS & 2016-01-04 & 2022-12-30 &         0 &  2552 &    0.000000 \\
#           4 &   TTWO & 2016-01-04 & 2022-12-30 &         0 &  2552 &    0.000000 \\
#           5 &   NFLX & 2016-01-04 & 2022-12-30 &         0 &  2552 &    0.000000 \\
#           6 &   ATVI & 2016-01-04 & 2022-12-30 &         0 &  2552 &    0.000000 \\
#           7 &    LYV & 2016-01-04 & 2022-12-30 &         0 &  2552 &    0.000000 \\
#           8 &     EA & 2016-01-04 & 2022-12-30 &         0 &  2552 &    0.000000 \\
#           9 &    WBD & 2022-04-11 & 2022-12-30 &         0 &   263 &    0.000000 \\
# ...
